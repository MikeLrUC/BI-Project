# %% [markdown]
# # Clustering

# %%
from load import main
df = main()
df
# Out:
#         rating  alcohol  price         lat         lng  age  category_Dessert  \
# 0           87      0.0     32 -200.000000 -200.000000   22                 0
# 1           92     14.5     56 -200.000000 -200.000000    7                 0
# 2           85      0.0     22 -200.000000 -200.000000   22                 0
# 3           90     15.0     19 -200.000000 -200.000000    9                 0
# 4           92     14.8     65 -200.000000 -200.000000   10                 0
# ...        ...      ...    ...         ...         ...  ...               ...
# 323116      88     12.5     12 -200.000000 -200.000000    2                 0
# 323117      80     13.4      9   36.436336  -99.398797   18                 0
# 323118      89     14.5      0  -31.761336  -71.318770    4                 0
# 323119      85     13.0     30   38.640500   24.047990   17                 0
# 323120      87     13.5     14 -200.000000 -200.000000   10                 0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
def worldwide_plot(feature):
    plt.figure(figsize=(10,10))
    plt.scatter(df["lng"], df["lat"], c=df[feature])
    plt.colorbar()
    plt.xlim([-180, 180])
    plt.ylim([-90, 90])
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(f"{feature.capitalize()} over the world");

# %%
worldwide_plot("rating")

# %%
worldwide_plot("alcohol")

# %%
worldwide_plot("price")

# %%
plt.figure(figsize=(10,10))
plt.scatter(df["alcohol"], df["price"], c=df["rating"])
plt.colorbar()
plt.xlabel("Alcohol")
plt.ylabel("Price")
plt.title(f"Rating over the alcohol and price");

# %%
plt.figure(figsize=(10,10))
plt.scatter(df["alcohol"], df["age"], c=df["rating"])
plt.colorbar()
plt.xlabel("Alcohol")
plt.ylabel("Age")
plt.title(f"Rating over the alcohol and age");

# %%
plt.figure(figsize=(10,10))
plt.scatter(df["age"], df["price"], c=df["rating"])
plt.colorbar()
plt.xlabel("Age")
plt.ylabel("Price")
plt.title(f"Rating over the age and price");
